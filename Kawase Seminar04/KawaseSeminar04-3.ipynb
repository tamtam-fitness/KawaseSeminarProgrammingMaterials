# %% [markdown]
# <p style="text-align:center"><font size="10" >Kawase Seminar 04-3
#     </font></p>

# %% [markdown]
# # **テキストマイニング入門**
# 04-1ではテキストマイニングの基礎となるデータ分析の説明していきます。
#
# 04-2ではPythonでデータ分析をするためのライブラリの勉強をしていきます。
#
# 04-3 ではテキストマイニングの実践として、歌詞メーカーを実装したものを読んでいきます。。

# %% [markdown]
# ### テキストマイニングの流れ
# 1. テキストの読み込み
#
# 2. 任意の方法で文字列を分割
#
# 3. 文字列を数値化などし分析

# %% [markdown]
# # 0. データセットのインストール
#
# テキストマイニングをしたいデータをセットします。
# git cloneで今回読み込むデータをインストールします。
#
# (データフォルダの中の「画像」フォルダには画像ファイル、「歌詞」のフォルダにいき分析した文字列が入ったtxtファイルをセットします)

# %%
# !git clone https://github.com/Densuke-fitness/pythonTextmining.git
# Out:
# Cloning into 'pythonTextmining'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 29 (delta 2), reused 26 (delta 1), pack-reused 0
# Unpacking objects: 100% (29/29), done.

# %% [markdown]
# <h1>1. ライブラリのインポート</h1>

# %%
# !pip install janome
# Out:
# Requirement already satisfied: janome in /usr/local/lib/python3.7/dist-packages (0.4.1)

# %%
# テキストマイニングで使うライブラリの数々
from gensim.models import word2vec
import re
import matplotlib as mplt
from matplotlib import rcParams
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
from PIL import Image
import os
from tqdm import tqdm
from IPython.display import clear_output
import time
# こちらは pip を使用
from janome.tokenizer import Tokenizer
from wordcloud import WordCloud, ImageColorGenerator

# %% [markdown]
# <h1>2. 関数の設定</h1>

# %%
# 記号かどうかを判別する関数
def find_kigou(string):
    for s in string:
        if s in ["!","?","[","]","(",")","「","」","！","？","（","）","'",'"',",","."]:
            return False
    return True

# %%
# 一文字だけの言葉を削除関数
def token(words,tokens,h):
    m = [chr(i) for i in range(12354,12354 + 82)]
    for token in tokens:
        word = token.surface
        hinsi = token.part_of_speech.split(',')[0]
        if hinsi == h:
            key = word
            if key not in words:
                if find_kigou(key):
                    # 一文字ひらがなの場合を削除
                    if len(key) == 1 and key not in m:
                        words[key] = 1
                    # 二文字ひらがなの場合を削除
                    if len(key) == 2 and (key[0] not in m and key[1] not in m):
                        words[key] = 1
                    # 三文字以上はすべて許可
                    if len(key) >= 3 :
                        words[key] = 1
            else:
                words[key] += 1
    return words

# %%
# 歌詞を読み込んで解析を行う関数
def kashi(kashi_path,n):
    #歌詞読み込み
    rdata = open(f"./pythonTextmining/データ/【歌詞】/{kashi_path}",'r',encoding="utf-8_sig")
    data = rdata.read().replace('\n', '')
    #形態素解析
    t = Tokenizer()
    tokens = t.tokenize(data)
    #名詞抽出
    words = {}
    words = token(words,tokens,"名詞")
    if len(words) <= 50:
        words = token(words,tokens,"形容詞")
    if len(words) <= 50:
        words = token(words,tokens,"副詞")
        
    #フォルダ作成        
    kyokumei = kashi_path.split(".")[0]
    os.mkdir(f"./pythonTextmining/データ/【画像】/{kyokumei}")
    #テキストマイニング＆保存
    for i in tqdm(range(n)):
        wordcloud = WordCloud(font_path="HGRGM.TTC",
                              regexp="[\w']+",
                              background_color='white',
                              colormap='jet',
                              width=800,
                              height=800)
        wordcloud.fit_words(words)
#         plt.imshow(wordcloud)
        plt.axis("off")
#         plt.show()
        wordcloud.to_file(f'./pythonTextmining/データ/【画像】/{kyokumei}/{i}.png')

# %%
# テキストマイニングのファイル内に歌詞名のファイルを作成してその中に作成↑
def make_txt_mining(n):
    count = 0
    kashi_list = os.listdir("./pythonTextmining/データ/【歌詞】")
    #for i in tqdm(range(len(kashi_list))):
    for i in range(len(kashi_list)):
        count += 1
        ka = kashi_list[i].split(".")[0]
        if not os.path.isdir(f"./pythonTextmining/データ/【画像】/{ka}"):
            kashi(kashi_list[i],n)
        if count < len(kashi_list):
            clear_output()

# %%
def kashi_mask(kashi_path,mask_path,n):
    #歌詞読み込み
    rdata = open(f"./pythonTextmining/データ/【歌詞】/{kashi_path}",'r',encoding="utf-8_sig")
    data = rdata.read().replace('\n', '')
    #マスク読み込み
    msk = np.array(Image.open(f"./pythonTextmining/データ/【mask】/{mask_path}"))
    #形態素解析
    t = Tokenizer()
    tokens = t.tokenize(data)
    #名詞抽出
    words = {}
    words = token(words,tokens,"名詞")
    if len(words) <= 30:
        words = token(words,tokens,"形容詞")
    if len(words) <= 30:
        words = token(words,tokens,"副詞")
    
    #フォルダ作成        
    kyokumei = kashi_path.split(".")[0]
    kyokumei_mask = kyokumei + "_mask"
    os.mkdir(f"./pythonTextmining/データ/【画像】/{kyokumei_mask}")
    maskname = mask_path.split(".")[0]
    #テキストマイニング＆保存
    for i in tqdm(range(n)):
        wordcloud = WordCloud(font_path="HGRGM.TTC",
                              font_step = 2, 
                              min_font_size = 1,
                              regexp="[\w']+",
                              #mode = "RGBA",
                              background_color = "aqua",#背景の色
                              mask=msk,
                              contour_width=5,#輪郭線の太さ
                              contour_color='yellow',#輪郭線の色
                              width=800,
                              height=800)
        wordcloud.fit_words(words)
        image_colors = ImageColorGenerator(msk)
        wordcloud.recolor(color_func=image_colors)        #文字の色にmaskの色を反映させる場合はこれ
        #plt.imshow(wordcloud,interpolation="bilinear")   #maskの色を考慮しない場合、上の行は消してこれ　
        plt.axis("off")
        #plt.show()
        wordcloud.to_file(f"./pythonTextmining/データ/【画像】/{kyokumei_mask}/{kyokumei}.png")

# %% [markdown]
# <h1>3. 関数呼び出し</h1>

# %%
import os
os.mkdir("./pythonTextmining/データ/【画像】")

# %%
make_txt_mining(1)

# %%
# 先ほど作成した関数を呼び出してあげる
kashi_mask("お願いマッスル.txt","まっちょ.jpg",1)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-36-83c6e7717017> in <module>()
#       1 # 先ほど作成した関数を呼び出してあげる
# ----> 2 kashi_mask("お願いマッスル.txt","まっちょ.jpg",1)
#
# <ipython-input-16-db962ce9955f> in kashi_mask(kashi_path, mask_path, n)
#      34                               width=800,
#      35                               height=800)
# ---> 36         wordcloud.fit_words(words)
#      37         image_colors = ImageColorGenerator(msk)
#      38         wordcloud.recolor(color_func=image_colors)        #文字の色にmaskの色を反映させる場合はこれ
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in fit_words(self, frequencies)
#     359         self
#     360         """
# --> 361         return self.generate_from_frequencies(frequencies)
#     362
#     363     def generate_from_frequencies(self, frequencies, max_font_size=None):  # noqa: C901
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     424             else:
#     425                 self.generate_from_frequencies(dict(frequencies[:2]),
# --> 426                                                max_font_size=self.height)
#     427                 # find font sizes
#     428                 sizes = [x[1] for x in self.layout_]
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     471             while True:
#     472                 # try to find a position
# --> 473                 font = ImageFont.truetype(self.font_path, font_size)
#     474                 # transpose font optionally
#     475                 transposed_font = ImageFont.TransposedFont(
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     646
#     647     try:
# --> 648         return freetype(font)
#     649     except OSError:
#     650         if not isPath(font):
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFont.py in freetype(font)
#     643
#     644     def freetype(font):
# --> 645         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     646
#     647     try:
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     192                     return
#     193             self.font = core.getfont(
# --> 194                 font, size, index, encoding, layout_engine=layout_engine
#     195             )
#     196         else:
#
# OSError: cannot open resource

# %% [markdown]
# 今回はエラーを吐いてしまったのでこちらが既製品、、涙
#
# https://twitter.com/ycufitness/status/1262056307432894469?s=20

# %% [markdown]
# #  Reference
# 今回は以前に田村が執筆した記事を参考に作成しています。興味がある方はぜひ見てください。
#
# - [Pythonでテキストマイニングをしよう！](https://defilabo.io/text_mining/#%E3%83%86%E3%82%AD%E3%82%B9%E3%83%88%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0%E3%81%A8%E3%81%AF)
#
# - [Pythonによるデータ分析① タイタニックの生存予測をしよう！](https://defilabo.io/python_dataanalysis_01/#%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90%E3%81%A8%E3%81%AF)
# - [Pythonで機械学習入門①教師あり学習編](https://defilabo.io/python_machinelearning_01/)
#
# その他の記事はこちら
# - [田村の記事まとめサイト](https://densuke.work/Articles.html)
